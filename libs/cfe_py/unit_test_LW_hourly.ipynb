# %% [markdown]
# ### This jupyter notebook is to unit-test CFE model run

# %% [markdown]
# ## Preparation

# %%
# Import modules
import json
from bmi_cfe import BMI_CFE

# %%
# Input: Little Washita data for 12 yrs
# forcing: LittleWashita/little_washita_2006_2012.csv
# observed: test_sm_basinavg


# Parameter: only limited number of parameters
# 	Unnamed: 0	like1	parbb	parsatdk	parsatpsi	parslop	parsmcmax	parwltsmc	parmax_gw_storage	parCgw	parexpon	parK_nash	parrefkdt	partrigger_z_fact	paralpha_fc	parK_lf	parnum_nash_storage
# 2869	2869	0.178421	3.291205	0.616596	0.78	0.029422	0.894693	0.095967	53.201708	0.0015	6.410308	0.227507	9990.000000	0.75	0.1	0.996	20.86379


# 	Unnamed: 0	like1	parbb	parsatdk	parsatpsi	parslop	parsmcmax	parwltsmc	parmax_gw_storage	parCgw	parexpon	parK_nash	parrefkdt	partrigger_z_fact	paralpha_fc	parK_lf	parD	parnum_nash_storage
# 592	592	0.876861	1.272496	0.000367	0.484279	0.000072	0.29342	0.002927	225.240689	9.625560	5.012957	0.047537	9990.000000	0.649522	0.10847	0.234793	100.0	80.706118

# 	Unnamed: 0	like1	    parbb	parsatdk	parsatpsi	parslop 	parsmcmax	parwltsmc	parmax_gw_storage	parCgw	    parexpon	parK_nash	parrefkdt	partrigger_z_fact	paralpha_fc	    parK_lf	        parD	    parnum_nash_storage
# 1468	1468	0.242275	0.0546	0.100876	0.769738	0.031752	0.344641	0.048044	419.597873	        3.171141	0.254816	0.407342	7688.784902	0.673953	        0.185811	    0.996	        44.226973	5.62484

# 	Unnamed: 0	like1	parbb	parsatdk	parsatpsi	parslop	parsmcmax	parwltsmc	parmax_gw_storage	parCgw	parexpon	parK_nash	parrefkdt	partrigger_z_fact	paralpha_fc	parK_lf	parD	parnum_nash_storage
# 1471	1471	0.211987	8.990886	0.060442	0.638266	0.87453	0.948077	0.012942	497.91655	1.522687	0.945915	0.3	7048.340683	0.695436	0.150908	0.000424	97.296499	100.0

input_json = '../../data/unit_test/config_cfe.json'
params = {
    "forcing_file": "G:/Shared drives/Ryoko and Hilary/SMSigxModel/analysis/data/LittleWashita/little_washita_2006_2012.csv",
    "catchment_area_km2": 601,
    "soil_params": {
        "bb": 3,
        "satdk": 0.0100876,
        "satpsi": 0.769738,
        "slop": 0.031752,
        "smcmax": 0.344641,
        "wltsmc": 0.048044,
        "D": 44.226973,
    },
    "max_gw_storage": 5,
    "Cgw": 0.3,
    "expon": 0.02,
    "K_nash": 0.407342,
    "refkdt":8000,
    "trigger_z_fact": 0.5,
    "alpha_fc": 0.185811,
    "K_lf": 0.001,
    "num_nash_storage": 5,
    "giuh_ordinates": [0.1, 0.4, 0.2, 0.2, 0.1], #[0.5, 0.5], #
    "stand_alone": 1,
    "unit_test": 1,
    "allow_percolation_below_threshold": 0,
    "revap_factor":1,
    "compare_results_file": "G:/Shared drives/Ryoko and Hilary/SMSigxModel/analysis/data/LittleWashita/test_sm_basinavg.csv",
}

with open(input_json, 'w') as outfile:
    json.dump(params, outfile, indent=4)

with open(input_json) as outfile:
    loaded_data = json.load(outfile)

# %% [markdown]
# ## Run the model

# %%
cfe_instance = BMI_CFE(input_json)
cfe_instance.initialize()
cfe_instance.run_unit_test(plot=True, print_fluxes=False, warm_up=True, warmup_offset=12000, warmup_iteration=10,)
cfe_instance.finalize(print_mass_balance=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# g:\Shared drives\Ryoko and Hilary\SMSigxModel\analysis\libs\cfe_py\unit_test_LW_hourly.ipynb Cell 6 line <cell line: 2>()
#       <a href='vscode-notebook-cell:/g%3A/Shared%20drives/Ryoko%20and%20Hilary/SMSigxModel/analysis/libs/cfe_py/unit_test_LW_hourly.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> cfe_instance = BMI_CFE(input_json)
# ----> <a href='vscode-notebook-cell:/g%3A/Shared%20drives/Ryoko%20and%20Hilary/SMSigxModel/analysis/libs/cfe_py/unit_test_LW_hourly.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> cfe_instance.initialize()
#       <a href='vscode-notebook-cell:/g%3A/Shared%20drives/Ryoko%20and%20Hilary/SMSigxModel/analysis/libs/cfe_py/unit_test_LW_hourly.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> cfe_instance.run_unit_test(plot=True, print_fluxes=False, warm_up=True, warmup_offset=12000, warmup_iteration=10,)
#       <a href='vscode-notebook-cell:/g%3A/Shared%20drives/Ryoko%20and%20Hilary/SMSigxModel/analysis/libs/cfe_py/unit_test_LW_hourly.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> cfe_instance.finalize(print_mass_balance=True)
#
# File g:\Shared drives\Ryoko and Hilary\SMSigxModel\analysis\libs\cfe_py\bmi_cfe.py:126, in BMI_CFE.initialize(self, current_time_step)
#     121     setattr(self, self.get_var_name(long_var_name), 0)
#     123 ############################################################
#     124 # ________________________________________________________ #
#     125 # GET VALUES FROM CONFIGURATION FILE.                      #
# --> 126 self.config_from_json()  #
#     128 # ________________________________________________
#     129 # The configuration should let the BMI know what mode to run in (framework vs standalone)
#     130 # If it is stand alone, then load in the forcing and read the time from the forcig file
#     131 if self.stand_alone == 1:
#
# File g:\Shared drives\Ryoko and Hilary\SMSigxModel\analysis\libs\cfe_py\bmi_cfe.py:420, in BMI_CFE.config_from_json(self)
#     417 # ___________________________________________________
#     418 # MANDATORY CONFIGURATIONS
#     419 self.forcing_file = data_loaded["forcing_file"]
# --> 420 self.time_step_size = data_loaded["time_step_size"]
#     421 self.catchment_area_km2 = data_loaded["catchment_area_km2"]
#     423 # SOIL PARAMETERS
#
# KeyError: 'time_step_size'

# %%
# plot close-look
plot_lim_closeup = list(range(40000, 45000))
cfe_instance.plot_flow(plot_lims=plot_lim_closeup)
cfe_instance.plot_SM(plot_lims=plot_lim_closeup)
for output_type in [
                "GW storage",
                "Nash storage",
                "GIUH storage",
            ]:
    cfe_instance.plot_other_fluxes(plot_lims=plot_lim_closeup, output_type=output_type)
