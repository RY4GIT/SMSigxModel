# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read data

# %%
filename = r"G:\Shared drives\Ryoko and Hilary\SMSigxModel\analysis\1_pre_calibration\results\Coweeta-2023-11-22-KGE-Flow-GLUEparams2\DDS_allresults.csv"
df = pd.read_csv(filename)
print(len(df))
df.head()
# Out:
# 500
#    Unnamed: 0     like1      parbb  parsatdk   parslop  parsmcmax  parwltsmc  \
# 0           0 -0.300005  17.209362  0.015782  0.894829   0.580235   0.219822
# 1           1 -0.896887  10.712665  0.013330  0.947784   0.322317   0.235191
# 2           2 -0.488954  11.893883  0.016740  0.741802   0.319987   0.157787
# 3           3 -0.561232   3.103570  0.016128  0.222701   0.617007   0.131057
# 4           4 -0.596107  12.130729  0.005898  0.259077   0.292228   0.207729
#
#    parmax_gw_storage
# 0           0.153377
# 1           0.114485
# 2           0.141370
# 3           0.087329
# 4           0.241102

# %%
parameter_names = ["parbb","parsatdk","parslop","parsmcmax","parwltsmc","parmax_gw_storage"]
# parameter_names = ["parbb","parsatdk","parslop","parsmcmax","parwltsmc","parmax_gw_storage","parCgw","parexpon","parK_nash","parrefkdt","partrigger_z_fact","parK_lf"] #,"parnum_nash_storage"]
# parameter_names = ["parbb","parsatdk","parsatpsi","parslop","parsmcmax","parwltsmc","parmax_gw_storage","parCgw","parexpon","parK_nash","parrefkdt","partrigger_z_fact","paralpha_fc","parK_lf","parD","parnum_nash_storage"]

# %% [markdown]
# ## Get dotty plots on the parameter values

# %%
num_plots = len(parameter_names)
fig, axes = plt.subplots(4, 4, figsize=(15, 12))  # Adjust figsize as needed
for i, parameter_name in enumerate(parameter_names):
    row, col = divmod(i, 4)
    axes[row, col].scatter(df[parameter_name].values, df["like1"].values, alpha=0.5)
    axes[row, col].set_xlabel(parameter_name)
    axes[row, col].set_ylabel("KGE")
    axes[row, col].set_ylim([-0.41, 1])
fig.tight_layout()

# %% [markdown]
# ## Get the best parameter sets

# %%
import numpy as np
df[df["like1"]==np.nanmax(df["like1"])]
# Out:
#      Unnamed: 0     like1     parbb  parsatdk  parslop  parsmcmax  parwltsmc  \
# 399         399  0.748556  2.240191  0.000006      1.0   0.739808   0.188566
# 416         416  0.748556  2.240191  0.000006      1.0   0.739808   0.188566
# 419         419  0.748556  2.240191  0.000006      1.0   0.739808   0.188566
# 424         424  0.748556  2.240191  0.000006      1.0   0.739808   0.188566
# 435         435  0.748556  2.240191  0.000006      1.0   0.739808   0.188566
# 436         436  0.748556  2.240191  0.000006      1.0   0.739808   0.188566
# 444         444  0.748556  2.240191  0.000006      1.0   0.739808   0.188566
# 452         452  0.748556  2.240191  0.000006      1.0   0.739808   0.188566
# 477         477  0.748556  2.240191  0.000006      1.0   0.739808   0.188566
# 482         482  0.748556  2.240191  0.000006      1.0   0.739808   0.188566
#
#      parmax_gw_storage
# 399            0.09158
# 416            0.09158
# 419            0.09158
# 424            0.09158
# 435            0.09158
# 436            0.09158
# 444            0.09158
# 452            0.09158
# 477            0.09158
# 482            0.09158
