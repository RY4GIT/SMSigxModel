# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
filename = r"G:\Shared drives\Ryoko and Hilary\SMSigxModel\analysis\1_pre_calibration\results\Mahurangi-2023-09-14\DDS_allresults.csv"

# %%
df = pd.read_csv(filename)
df.head()
# Out:
#    Unnamed: 0     like1      parbb  parsatdk  parsatpsi   parslop  parsmcmax  \
# 0           0 -0.228712   5.469175  0.005483   0.375769  0.097597   0.484304
# 1           1  0.094878  11.330526  0.003988   0.701919  0.646874   0.626761
# 2           2 -0.026345  19.366491  0.007265   0.125520  0.722814   0.987901
# 3           3  0.035981  17.623945  0.003633   0.774849  0.765888   0.620782
# 4           4 -0.063727  16.427091  0.007968   0.543332  0.329048   0.795045
#
#    parwltsmc  parmax_gw_storage    parCgw  parexpon  parK_nash  parrefkdt  \
# 0   0.411006         473.825516  4.102843  4.406764   0.933388   1.897176
# 1   0.030793         343.754539  3.496901  3.857281   0.991835   0.089537
# 2   0.423026         101.893629  3.747195  2.624567   0.112543   2.593433
# 3   0.092422         470.130154  7.428215  2.715893   0.002392   0.852836
# 4   0.355879         376.337054  6.903076  5.738985   0.705852   0.985893
#
#    partrigger_z_fact  paralpha_fc   parK_lf  parnum_nash_storage
# 0           0.266342     0.199998  0.547550             9.263654
# 1           0.618190     0.281974  0.508069             6.310176
# 2           0.717195     0.226285  0.196178             3.518457
# 3           0.483043     0.249657  0.584825             9.313602
# 4           0.475028     0.225370  0.249566             2.659272

# %%
parameter_names = ["parbb","parsatdk","parsatpsi","parslop","parsmcmax","parwltsmc","parmax_gw_storage","parCgw","parexpon","parK_nash","parrefkdt","partrigger_z_fact","paralpha_fc","parK_lf","parnum_nash_storage"]
# parameter_names = ["parbb","parsatdk","parsatpsi","parslop","parsmcmax","parwltsmc","parmax_gw_storage","parCgw","parexpon","parK_nash","parrefkdt","partrigger_z_fact","paralpha_fc","parK_lf","parD","parnum_nash_storage"]

# %%
num_plots = len(parameter_names)
fig, axes = plt.subplots(4, 4, figsize=(15, 12))  # Adjust figsize as needed
for i, parameter_name in enumerate(parameter_names):
    row, col = divmod(i, 4)
    axes[row, col].scatter(df[parameter_name].values, df["like1"].values, alpha=0.5)
    axes[row, col].set_xlabel(parameter_name)
    axes[row, col].set_ylabel("KGE")
    axes[row, col].set_ylim([-1, 1])
fig.tight_layout()

# %%
import numpy as np
df[df["like1"]==np.nanmax(df["like1"])]
# Out:
#      Unnamed: 0     like1     parbb  parsatdk  parsatpsi   parslop  parsmcmax  \
# 978         978  0.921414  2.553518  0.000147     0.0691  0.007217   0.552437
# 983         983  0.921414  2.553518  0.000147     0.0691  0.007217   0.552437
# 996         996  0.921414  2.553518  0.000147     0.0691  0.007217   0.552437
# 997         997  0.921414  2.553518  0.000147     0.0691  0.007217   0.552437
#
#      parwltsmc  parmax_gw_storage    parCgw  parexpon  parK_nash  parrefkdt  \
# 978    0.38771         343.449845  8.484384  1.821161     0.0013   3.620361
# 983    0.38771         343.449845  8.484384  1.821161     0.0013   3.620361
# 996    0.38771         343.449845  8.484384  1.821161     0.0013   3.620361
# 997    0.38771         343.449845  8.484384  1.821161     0.0013   3.620361
#
#      partrigger_z_fact  paralpha_fc   parK_lf  parnum_nash_storage
# 978               0.75      0.13743  0.000424             4.058391
# 983               0.75      0.13743  0.000424             4.058391
# 996               0.75      0.13743  0.000424             4.058391
# 997               0.75      0.13743  0.000424             4.058391

# %%
filename = r"G:\Shared drives\Ryoko and Hilary\SMSigxModel\analysis\1_pre_calibration\results\Mahurangi-2023-09-14\DDS_bestrun_Q.csv"
data = np.genfromtxt(filename, delimiter=',')
plt.plot(data)
