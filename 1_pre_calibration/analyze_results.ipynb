# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read data

# %%
filename = r"G:\Shared drives\Ryoko and Hilary\SMSigxModel\analysis\1_pre_calibration\results\Coweeta-2023-10-23-KGE-SM-smallGW\DDS_allresults.csv"
df = pd.read_csv(filename)
print(len(df))
df.head()
# Out:
# 500
#    Unnamed: 0     like1      parbb  parsatdk  parsatpsi   parslop  parsmcmax  \
# 0           0 -0.242000   5.494107  0.054832   0.465691  0.097597   0.333967
# 1           1  0.434525  11.382237  0.039875   0.695083  0.646874   0.517758
# 2           2 -1.042735  19.454916  0.072646   0.289682  0.722814   0.983681
# 3           3  0.381661  17.704409  0.036330   0.746377  0.765888   0.510043
# 4           4 -0.307615  16.502086  0.079680   0.583543  0.329048   0.734868
#
#    parwltsmc  parmax_gw_storage    parCgw  parexpon  parK_nash    parrefkdt  \
# 0   0.264870           0.237436  0.073852  4.855120   0.933388  4750.070059
# 1   0.019844           0.175001  0.062945  4.374201   0.991835   224.177234
# 2   0.272617           0.058905  0.067451  3.295302   0.112543  6493.331021
# 3   0.059560           0.235662  0.133708  3.375233   0.002392  2135.293933
# 4   0.229344           0.190641  0.124256  6.021109   0.705852  2468.436526
#
#    partrigger_z_fact  paralpha_fc   parK_lf  parnum_nash_storage
# 0           0.266342     0.199998  0.547550                  2.0
# 1           0.618190     0.281974  0.508069                  2.0
# 2           0.717195     0.226285  0.196178                  2.0
# 3           0.483043     0.249657  0.584825                  2.0
# 4           0.475028     0.225370  0.249566                  2.0

# %%
parameter_names = ["parbb","parsatdk","parsatpsi","parslop","parsmcmax","parwltsmc","parmax_gw_storage","parCgw","parexpon","parK_nash","parrefkdt","partrigger_z_fact","paralpha_fc","parK_lf","parnum_nash_storage"]
# parameter_names = ["parbb","parsatdk","parsatpsi","parslop","parsmcmax","parwltsmc","parmax_gw_storage","parCgw","parexpon","parK_nash","parrefkdt","partrigger_z_fact","paralpha_fc","parK_lf","parD","parnum_nash_storage"]

# %% [markdown]
# ## Get dotty plots on the parameter values

# %%
num_plots = len(parameter_names)
fig, axes = plt.subplots(4, 4, figsize=(15, 12))  # Adjust figsize as needed
for i, parameter_name in enumerate(parameter_names):
    row, col = divmod(i, 4)
    axes[row, col].scatter(df[parameter_name].values, df["like1"].values, alpha=0.5)
    axes[row, col].set_xlabel(parameter_name)
    axes[row, col].set_ylabel("KGE")
    axes[row, col].set_ylim([-0.41, 1])
fig.tight_layout()

# %% [markdown]
# ## Get the best parameter sets

# %%
import numpy as np
df[df["like1"]==np.nanmax(df["like1"])]
# Out:
#      Unnamed: 0     like1      parbb  parsatdk  parsatpsi   parslop  \
# 495         495  0.942565  15.263313  0.007003   0.371111  0.054171
# 497         497  0.942565  15.263313  0.007003   0.371111  0.054171
# 499         499  0.942565  15.263313  0.007003   0.371111  0.054171
#
#      parsmcmax  parwltsmc  parmax_gw_storage    parCgw  parexpon  parK_nash  \
# 495      0.451   0.262358            0.11766  0.005237  2.347989   0.237986
# 497      0.451   0.262358            0.11766  0.005237  2.347989   0.237986
# 499      0.451   0.262358            0.11766  0.005237  2.347989   0.237986
#
#        parrefkdt  partrigger_z_fact  paralpha_fc   parK_lf  \
# 495  5760.499629           0.715412     0.325118  0.879771
# 497  5760.499629           0.715412     0.325118  0.879771
# 499  5760.499629           0.715412     0.325118  0.879771
#
#      parnum_nash_storage
# 495              29.6803
# 497              29.6803
# 499              29.6803
